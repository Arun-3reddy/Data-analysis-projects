# %% [markdown]
# <a href="https://colab.research.google.com/github/Arun-3reddy/Data-analysis-projects/blob/main/Bigsales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#importing dataset
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Big%20Sales%20Data.csv')

# %%
# show the top 5 rows
df.head()
#df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
# 2           FDT36         12.3               LF         0.111728
# 3           FDT36         12.3          Low Fat         0.000000
# 4           FDP12          9.8          Regular         0.045523
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
# 2  Baking Goods   33.9874            OUT018                       2009
# 3  Baking Goods   34.3874            OUT019                       1985
# 4  Baking Goods   35.0874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# ...

# %%
# Give the complete information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11815 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# GEt column name

# %%
# show only the columns names
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# shows the stastical information about all columns
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11815.000000     14204.000000  14204.000000               14204.000000
# mean      12.788355         0.065953    141.004977                1997.830681
# std        4.654126         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.500000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       30.000000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count       14204.000000
# mean         2185.836320
# std          1827.479550
# min            33.290000
# 25%           922.135101
# 50%          1768.287680
# 75%          2988.110400
# max         31224.726950

# %%
#selecting the particular column and show only top five rows
df['Item_Identifier'].head()
# Out:
# 0    FDT36
# 1    FDT36
# 2    FDT36
# 3    FDT36
# 4    FDP12
# Name: Item_Identifier, dtype: object

# %%
#Viewing and inspecting data
#df.head()
#df.tail()
#df.describe()
#df.info()
#df.shape()
df['Item_Identifier'].value_counts()
# Out:
# Item_Identifier
# FDT36    10
# FDG09    10
# FDZ56    10
# FDT19    10
# FDD56    10
#          ..
# NCW54     7
# FDS22     7
# FDM50     7
# FDX49     7
# DRN11     7
# Name: count, Length: 1559, dtype: int64

# %%
#aggregate function on particular columns
#df ['Item_Weight'].max()
#df ['Item_Weight'].min()
#df ['Item_Weight'].median()
#df ['Item_Weight'].describe()
#df ['Item_Weight'].count()
#df ['Item_Weight'].mean()
#df['Item_Weight'].std()
df ['Item_Weight'].corr(df['Item_MRP'])
# Out:
# 0.03728832197353381

# %%
#sorting and cleaning
greater=df[df['Item_Weight']<9].head()
greater
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6            FDQ36        7.855          Regular         0.161413
# 7            FDT36        7.855          Low Fat         0.110736
# 8            FDQ36        7.855          Regular         0.161875
# 13           FDQ36        7.855          Regular         0.162206
# 15           FDP12        5.765          Regular         0.045048
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 6   Baking Goods   35.2848            OUT013                       1987
# 7   Baking Goods   35.2874            OUT027                       1985
# 8   Baking Goods   35.6848            OUT045                       2002
# 13  Baking Goods   36.2848            OUT018                       2009
# 15  Baking Goods   36.4874            OUT027                       1985
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.Item_Weight>12
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 14199     True
# 14200     True
# 14201     True
# 14202    False
# 14203     True
# Name: Item_Weight, Length: 14204, dtype: bool

# %%
not_na= df[df['Item_Weight'].isnull()]
not_na
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 269             FDH48          NaN          Low Fat         0.105893
# 272             FDS24          NaN          Regular         0.108947
# 279             FDS24          NaN          Regular         0.061923
# 280             FDC60          NaN          Regular         0.113918
# 287             FDL36          NaN          Low Fat         0.075707
# ...               ...          ...              ...              ...
# 14176           FDF11          NaN          Regular         0.000000
# 14188           FDD11          NaN          Low Fat         0.053606
# 14192           FDD11          NaN          Low Fat         0.030468
# 14197           FDG47          NaN          Low Fat         0.121894
# 14202           FDG47          NaN          Low Fat         0.069282
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
not_na=df[df['Item_Weight'].notna()]
not_na
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDT36         12.3          Low Fat         0.111448
# 1               FDT36         12.3          Low Fat         0.111904
# 2               FDT36         12.3               LF         0.111728
# 3               FDT36         12.3          Low Fat         0.000000
# 4               FDP12          9.8          Regular         0.045523
# ...               ...          ...              ...              ...
# 14198           FDG47         12.8          Low Fat         0.116528
# 14199           FDG47         12.8          Low Fat         0.069606
# 14200           FDG47         12.8          Low Fat         0.070013
# 14201           FDG47         12.8          Low Fat         0.069561
# 14203           FDG47         12.8          Low Fat         0.069727
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
not_na.shape
# Out:
# (11815, 12)

# %%
df.plot()
plt.show()

# %%
df['Item_Weight'].plot()
plt.show()

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
# 2           FDT36         12.3               LF         0.111728
# 3           FDT36         12.3          Low Fat         0.000000
# 4           FDP12          9.8          Regular         0.045523
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
# 2  Baking Goods   33.9874            OUT018                       2009
# 3  Baking Goods   34.3874            OUT019                       1985
# 4  Baking Goods   35.0874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# ...

# %%
df["Item_Weight"].mean()
# Out:
# 12.788355480321624

# %%
df[["Item_Weight","Item_MRP"]].median()
# Out:
# Item_Weight     12.500
# Item_MRP       142.247
# dtype: float64

# %%
df[["Item_Identifier", "Item_Weight","Item_MRP"]].groupby('Item_Identifier').mean()
# Out:
#                  Item_Weight    Item_MRP
# Item_Identifier
# DRA12                 11.600  141.682067
# DRA24                 19.350  164.016800
# DRA59                  8.270  184.982400
# DRB01                  7.390  189.890500
# DRB13                  6.115  189.797444
# ...                      ...         ...
# NCZ30                  6.590  121.009800
# NCZ41                 19.850  125.757900
# NCZ42                 10.500  236.954800
# NCZ53                  9.600  188.554733
# NCZ54                 14.650  162.135200
#
# [1559 rows x 2 columns]

# %%
null=[df['Item_Weight'].isnull().sum()]
null
# Out:
# [2389]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# combining two columns
df['Outlet_Location_Type and Outlet_Type']= df['Outlet_Location_Type']+df['Outlet_Type']
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
# 2           FDT36         12.3               LF         0.111728
# 3           FDT36         12.3          Low Fat         0.000000
# 4           FDP12          9.8          Regular         0.045523
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
# 2  Baking Goods   33.9874            OUT018                       2009
# 3  Baking Goods   34.3874            OUT019                       1985
# 4  Baking Goods   35.0874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
# deleting columns
df.drop('Item_Visibility',axis=1,inplace=True)
df.head()
# Out:
#   Item_Identifier Item_Fat_Content     Item_Type  Item_MRP Outlet_Identifier  \
# 0           FDT36          Low Fat  Baking Goods   33.4874            OUT049
# 1           FDT36          Low Fat  Baking Goods   33.9874            OUT017
# 2           FDT36               LF  Baking Goods   33.9874            OUT018
# 3           FDT36          Low Fat  Baking Goods   34.3874            OUT019
# 4           FDP12          Regular  Baking Goods   35.0874            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
# 2                       2009      Medium               Tier 3
# 3                       1985       Small               Tier 1
# 4                       2007      Medium               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales Outlet_Location_Type and Outlet_Type
# ...

# %%
# sorting values
df.sort_values(by='Outlet_Establishment_Year',ascending=True).head()
# Out:
#       Item_Identifier Item_Fat_Content              Item_Type  Item_MRP  \
# 5503            FDG44          Low Fat  Fruits and Vegetables   55.7298
# 2543            FDK26          Regular                 Canned  187.5240
# 6662            FDJ44          Regular  Fruits and Vegetables  175.0396
# 11726           FDT34          Low Fat            Snack Foods  105.5964
# 11725           FDQ34               LF            Snack Foods  105.5622
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 5503             OUT019                       1985       Small
# 2543             OUT027                       1985      Medium
# 6662             OUT027                       1985      Medium
# 11726            OUT019                       1985       Small
# 11725            OUT019                       1985       Small
#
#       Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 5503                Tier 1      Grocery Store         161.789400
# ...

# %%
df.sort_values(by='Item_Fat_Content')
# Out:
#       Item_Identifier Item_Fat_Content              Item_Type  Item_MRP  \
# 9662            NCX06               LF              Household  181.5976
# 2502            FDD14               LF                 Canned  184.2266
# 13170           FDK46               LF            Snack Foods  258.9620
# 13166           FDM21               LF            Snack Foods  258.3646
# 2498            FDX25               LF                 Canned  184.0292
# ...               ...              ...                    ...       ...
# 13006           FDN58              reg            Snack Foods  230.0984
# 13001           FDI34              reg            Snack Foods  229.7668
# 918             FDM12              reg           Baking Goods  189.2214
# 957             FDH60              reg           Baking Goods  197.0110
# 5402            FDH45              reg  Fruits and Vegetables   42.8796
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
df[['Item_Fat_Content',"Item_Type","Item_MRP"]].groupby('Item_Fat_Content')
# grouping values

# %%
# replaceing values
df['Item_Fat_Content'].replace('LF','Low Fat')
# Out:
# 0        Low Fat
# 1        Low Fat
# 2        Low Fat
# 3        Low Fat
# 4        Regular
#           ...
# 14199    Low Fat
# 14200    Low Fat
# 14201    Low Fat
# 14202    Low Fat
# 14203    Low Fat
# Name: Item_Fat_Content, Length: 14204, dtype: object

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'LF', 'Regular', 'reg', 'low fat'], dtype=object)

# %%
# converting values into epper
df['Item_Fat_Content']=df['Item_Fat_Content'].str.upper()
df.head()
# Out:
#   Item_Identifier Item_Fat_Content     Item_Type  Item_MRP Outlet_Identifier  \
# 0           FDT36          LOW FAT  Baking Goods   33.4874            OUT049
# 1           FDT36          LOW FAT  Baking Goods   33.9874            OUT017
# 2           FDT36               LF  Baking Goods   33.9874            OUT018
# 3           FDT36          LOW FAT  Baking Goods   34.3874            OUT019
# 4           FDP12          REGULAR  Baking Goods   35.0874            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
# 2                       2009      Medium               Tier 3
# 3                       1985       Small               Tier 1
# 4                       2007      Medium               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales Outlet_Location_Type and Outlet_Type
# ...

# %%
#selecting by position
df.loc[4:10,['Item_Identifier','Item_Fat_Content']]
# Out:
#    Item_Identifier Item_Fat_Content
# 4            FDP12          Regular
# 5            FDT36          Low Fat
# 6            FDQ36          Regular
# 7            FDT36          Low Fat
# 8            FDQ36          Regular
# 9            FDT36          Low Fat
# 10           FDP12          Regular

# %%
df.loc[df['Item_Fat_Content'] =='REGULAR',]
# Out:
#       Item_Identifier Item_Fat_Content      Item_Type  Item_MRP  \
# 4               FDP12          REGULAR   Baking Goods   35.0874
# 6               FDQ36          REGULAR   Baking Goods   35.2848
# 8               FDQ36          REGULAR   Baking Goods   35.6848
# 10              FDP12          REGULAR   Baking Goods   35.9874
# 12              FDP12          REGULAR   Baking Goods   36.1874
# ...               ...              ...            ...       ...
# 14180           FDF11          REGULAR  Starchy Foods  239.6538
# 14181           FDF11          REGULAR  Starchy Foods  239.6538
# 14182           FDF11          REGULAR  Starchy Foods  239.8538
# 14183           FDF11          REGULAR  Starchy Foods  240.1538
# 14184           FDF11          REGULAR  Starchy Foods  240.6538
#
#       Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4                OUT017                       2007      Medium
# 6                OUT013                       1987        High
# ...

# %%
#creating DataFrame
data=pd.DataFrame({
    'Employe': ['arun','chinnu','reddy','shiva','chamak','aravind'],
    'salary' :['12222','3333','4444','8888','3333','null'],
    'ID':['1','2','3','4','5','6']
})
data
# Out:
#    Employe salary ID
# 0     arun  12222  1
# 1   chinnu   3333  2
# 2    reddy   4444  3
# 3    shiva   8888  4
# 4   chamak   3333  5
# 5  aravind   null  6

# %%
data['salary']
# Out:
# 0    12222
# 1     3333
# 2     4444
# 3     8888
# 4     3333
# 5     null
# Name: salary, dtype: object

# %%
data[0:2]
# Out:
#   Employe salary ID
# 0    arun  12222  1
# 1  chinnu   3333  2

# %%
data['salary'].unique()
# Out:
# array(['12222', '3333', '4444', '8888', 'null'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Employe    0
# salary     0
# ID         0
# dtype: int64

# %%
data['salary'].replace('null','1234')
# Out:
# 0    12222
# 1     3333
# 2     4444
# 3     8888
# 4     3333
# 5     1234
# Name: salary, dtype: object

# %%
data['ID']>'2'
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: ID, dtype: bool

# %%
data2= pd.DataFrame({
    'name':['arun','ravi','vamshi','shiva'],
    'salary':['7777','7778','6664',' '],
    'ID':['1','2','3','4']
})
data2
# Out:
#      name salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# 3   shiva         4

# %%
inner_joint=pd.merge(data,data2,on="ID")
inner_joint
# Out:
#   Employe salary_x ID    name salary_y
# 0    arun    12222  1    arun     7777
# 1  chinnu     3333  2    ravi     7778
# 2   reddy     4444  3  vamshi     6664

# %%
right_joint=pd.merge(data,data2,on='salary',how='right')
right_joint
# Out:
#   Employe salary ID_x    name ID_y
# 0     NaN   7777  NaN    arun    1
# 1     NaN   7778  NaN    ravi    2
# 2     NaN   6664  NaN  vamshi    3

# %%
left_joint=pd.merge(data,data2,on='ID',how='left')
left_joint
# Out:
#    Employe salary_x ID    name salary_y
# 0     arun    12222  1    arun     7777
# 1   chinnu     3333  2    ravi     7778
# 2    reddy     4444  3  vamshi     6664
# 3    shiva     8888  4     NaN      NaN
# 4   chamak     3333  5     NaN      NaN
# 5  aravind     null  6     NaN      NaN

# %%
#outer joint
outer_joint=pd.merge(data,data2,on="ID",how='outer')
outer_joint
# Out:
#    Employe salary_x ID    name salary_y
# 0     arun    12222  1    arun     7777
# 1   chinnu     3333  2    ravi     7778
# 2    reddy     4444  3  vamshi     6664
# 3    shiva     8888  4     NaN      NaN
# 4   chamak     3333  5     NaN      NaN
# 5  aravind     null  6     NaN      NaN

# %%
dataframe=pd.DataFrame(np.random.randn(10,4))
dataframe
# Out:
#           0         1         2         3
# 0  1.619301  0.604233  1.179369  0.297071
# 1 -0.833263  0.240046  1.790874 -1.259282
# 2 -1.636434  1.141729  0.283810  0.529991
# 3  0.049006 -0.476389  1.653522  0.043881
# 4  0.328229  0.831669  1.008665  1.154239
# 5  0.346437 -0.535120  0.324295 -0.519102
# 6 -2.305185  0.593225 -0.154868  0.327882
# 7  0.670462  2.077970 -0.328847  0.030841
# 8 -0.592551 -0.871430 -0.788966 -0.323815
# 9 -2.278730 -0.306568  0.327668 -1.042126

# %%
df=pd.Series(['arun','kumar','kaki','arun'],[12,23,34,32])
df
# Out:
# 12     arun
# 23    kumar
# 34     kaki
# 32     arun
# dtype: object

# %%
df.apply(df.value_counts)
# Out:
#     arun  kumar  kaki
# 12   0.5   0.25  0.25
# 23   0.5   0.25  0.25
# 34   0.5   0.25  0.25
# 32   0.5   0.25  0.25

# %%
df.value_counts()
# Out:
# arun     2
# kumar    1
# kaki     1
# Name: count, dtype: int64

# %%
df
# Out:
# 12     arun
# 23    kumar
# 34     kaki
# 32     arun
# dtype: object

# %%
data2[['name','salary']]
# Out:
#      name salary
# 0    arun   7777
# 1    ravi   7778
# 2  vamshi   6664
# 3   shiva

# %%
data2.iloc[1:2]
# Out:
#    name salary ID
# 1  ravi   7778  2

# %%
data2.rename(columns ={'name':'Nameid'})
# Out:
#    Nameid salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Nameid').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('salary').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
# ...

# %%
data2.isnull()
# Out:
#     name  salary     ID
# 0  False   False  False
# 1  False   False  False
# 2  False   False  False

# %%
data2.notnull()
# Out:
#    name  salary    ID
# 0  True    True  True
# 1  True    True  True
# 2  True    True  True

# %%
data2.dropna()
# Out:
#      name salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# 3   shiva         4

# %%
data2.dropna(axis=1)
# Out:
#      name salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# 3   shiva         4

# %%
data2.replace([1,2],['one','two'])
# Out:
#      name salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# 3   shiva         4
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('salary').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
# ...

# %%
data2.replace(['one','three'], ['1','2'])
# Out:
#      name salary ID
# 0    arun   7777  1
# 1    ravi   7778  2
# 2  vamshi   6664  3
# 3   shiva         4

# %%
Series=pd.Series(data=["arun","chnnn"],index=[1,2])
Series
# Out:
# 1     arun
# 2    chnnn
# dtype: object

# %%
df.groupby(['Item_Identifier','Item_Weight'])
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDT36         12.3          Low Fat         0.111448
# 1               FDT36         12.3          Low Fat         0.111904
# 2               FDT36         12.3               LF         0.111728
# 3               FDT36         12.3          Low Fat         0.000000
# 4               FDP12          9.8          Regular         0.045523
# ...               ...          ...              ...              ...
# 14199           FDG47         12.8          Low Fat         0.069606
# 14200           FDG47         12.8          Low Fat         0.070013
# 14201           FDG47         12.8          Low Fat         0.069561
# 14202           FDG47          NaN          Low Fat         0.069282
# 14203           FDG47         12.8          Low Fat         0.069727
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.notna().sum()
# Out:
# Item_Identifier              14204
# Item_Weight                  11815
# Item_Fat_Content             14204
# Item_Visibility              14204
# Item_Type                    14204
# Item_MRP                     14204
# Outlet_Identifier            14204
# Outlet_Establishment_Year    14204
# Outlet_Size                  14204
# Outlet_Location_Type         14204
# Outlet_Type                  14204
# Item_Outlet_Sales            14204
# dtype: int64

# %%
df[df['Item_Weight']<9]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6               FDQ36        7.855          Regular         0.161413
# 7               FDT36        7.855          Low Fat         0.110736
# 8               FDQ36        7.855          Regular         0.161875
# 13              FDQ36        7.855          Regular         0.162206
# 15              FDP12        5.765          Regular         0.045048
# ...               ...          ...              ...              ...
# 14142           FDC35        7.435          Low Fat         0.123087
# 14143           FDC35        7.435               LF         0.122814
# 14145           FDC35        7.435          Low Fat         0.205605
# 14146           FDC35        7.435          Low Fat         0.123029
# 14148           FDC35        7.435          Low Fat         0.122838
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.groupby(['Item_Identifier','Item_Weight'])
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDT36         12.3          Low Fat         0.111448
# 1               FDT36         12.3          Low Fat         0.111904
# 2               FDT36         12.3               LF         0.111728
# 3               FDT36         12.3          Low Fat         0.000000
# 4               FDP12          9.8          Regular         0.045523
# ...               ...          ...              ...              ...
# 14199           FDG47         12.8          Low Fat         0.069606
# 14200           FDG47         12.8          Low Fat         0.070013
# 14201           FDG47         12.8          Low Fat         0.069561
# 14202           FDG47          NaN          Low Fat         0.069282
# 14203           FDG47         12.8          Low Fat         0.069727
#
#            Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.016348  0.037288
# Item_Visibility              -0.016348         1.000000 -0.006351
# Item_MRP                      0.037288        -0.006351  1.000000
# Outlet_Establishment_Year     0.002878        -0.083678  0.000141
# Item_Outlet_Sales             0.228297        -0.158813  0.532261
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                 0.002878           0.228297
# Item_Visibility                            -0.083678          -0.158813
# Item_MRP                                    0.000141           0.532261
# Outlet_Establishment_Year                   1.000000          -0.110786
# Item_Outlet_Sales                          -0.110786           1.000000

# %%
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11815.000000     14204.000000  14204.000000               14204.000000
# mean      12.788355         0.065953    141.004977                1997.830681
# std        4.654126         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.500000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       30.000000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count       14204.000000
# mean         2185.836320
# std          1827.479550
# min            33.290000
# 25%           922.135101
# 50%          1768.287680
# 75%          2988.110400
# max         31224.726950

# %%
combine=pd.concat([data,data2])
combine
# Out:
#    Employe salary ID    name
# 0     arun  12222  1     NaN
# 1   chinnu   3333  2     NaN
# 2    reddy   4444  3     NaN
# 3    shiva   8888  4     NaN
# 4   chamak   3333  5     NaN
# 5  aravind   null  6     NaN
# 0      NaN   7777  1    arun
# 1      NaN   7778  2    ravi
# 2      NaN   6664  3  vamshi
# 3      NaN         4   shiva
