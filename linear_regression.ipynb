# %% [markdown]
# <a href="https://colab.research.google.com/github/Arun-3reddy/Data-analysis-projects/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
salary=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.isna().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y = salary['Salary']
x = salary[['Experience Years']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=2323)
x_train
# Out:
#     Experience Years
# 1                1.2
# 12               3.7
# 15               4.0
# 23               5.3
# 27               6.2
# 28               6.5
# 32               8.2
# 25               5.9
# 0                1.1
# 24               5.5
# 16               4.0
# 4                2.0
# 13               3.8
# 34               8.7
# 6                2.5
# 29               6.8
# 5                2.2
# 31               7.9
# 22               5.1
# 2                1.3
# 7                2.9
# 14               3.9
# 38              10.3
# 20               4.7
# 11               3.5
# 26               6.0
# 33               8.5
# 39              10.5
# 19               4.5
# 8                3.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_train['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 25786.380530883063

# %%
model.coef_
# Out:
# array([9632.32855093])

# %%
#prediction
y_pred=model.predict(x_test)

# %%
#accuracy
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.0742533969529207
